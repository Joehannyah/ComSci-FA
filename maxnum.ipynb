# %% [markdown]
# <a href="https://colab.research.google.com/github/Joehannyah/ComSci-FA/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

#time to determine the largest number
if num1 >= num2 and num1 >= num3:
    print("The largest number is", num1)
if num2 >= num1 and num2 >= num3:
    print("The largest number is", num2)
if num3 >= num2 and num3 >= num1:
    print("The largest number is", num3)
# Out:
# Enter the first number: 10
# Enter the second number: 11
# Enter the third number: 12
# The largest number is 12
